# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
path = "/Users/aidanwiteck/Desktop/Princeton/Year 4/Thesis/electricgrid/data/final_tables/banc/banc.csv"
df = pd.read_csv(path)
df['timestamp'] = pd.to_datetime(df['timestamp'])

# %%
df.head()
# Out:
#             timestamp  Demand (MWh)  Demand Forecast (MWh)  \
# 0 2015-07-01 01:00:00        2513.0                 2226.0
# 1 2015-07-01 02:00:00        2275.0                 2035.0
# 2 2015-07-01 03:00:00        2104.0                 1897.0
# 3 2015-07-01 04:00:00        1988.0                 1821.0
# 4 2015-07-01 05:00:00        1958.0                 1811.0
#
#    Net Generation (MWh) Region  temperature  humidity  cloudcover  windspeed
# 0                1559.0   banc         38.5        18          10        8.7
# 1                1441.0   banc         37.7        19          12       10.4
# 2                1399.0   banc         35.4        23          11       10.7
# 3                1354.0   banc         32.5        27          16       11.4
# 4                1334.0   banc         30.3        31          21        9.0

# %%
plt.scatter(range(24*7),df["Demand (MWh)"][10000:10000+24*7])

# %%
plt.plot(range(24*7),df["Demand (MWh)"][10000:10000+24*7])
plt.xlabel("Hour")
plt.ylabel("Demand (MWh)")
plt.title("Electric Demand Over One Week")
# Out:
# Text(0.5, 1.0, 'Electric Demand Over One Week')

# %%
plt.plot(range(24*70),df["Demand (MWh)"][10000:10000+24*70])
plt.xlabel("Hour")
plt.ylabel("Demand (MWh)")
plt.title("Electric Demand Over Ten Weeks")
# Out:
# Text(0.5, 1.0, 'Electric Demand Over Ten Weeks')
