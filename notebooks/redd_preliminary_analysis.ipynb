# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
path = "../data/greend/"

# %%
example_df = pd.read_csv(path + "building0/dataset_2014-04-20.csv")
# example_df.drop(["Unnamed: 0"], axis=1)

# %%
example_df
# Out:
#                timestamp 000D6F0002906FA7 000D6F0002907BA2  \
# 0      1397951641.191078              0.0              0.0
# 1       1397951642.21573              0.0              0.0
# 2      1397951643.366016              0.0              0.0
# 3      1397951644.459238              0.0              0.0
# 4      1397951645.631246              0.0              0.0
# ...                  ...              ...              ...
# 83294  1398038090.913562              0.0              0.0
# 83295  1398038091.934425              0.0              0.0
# 83296  1398038092.917223              0.0              0.0
# 83297  1398038094.360224              0.0              NaN
# 83298  1398038095.424884              0.0              NaN
#
#          000D6F0002907BC8 000D6F0002907BDF   000D6F0002907BF5  \
# 0                     0.0              NaN  94.41949067328446
# 1                     0.0              NaN  94.41949067328446
# 2                     0.0              NaN  94.41949067328446
# ...

# %%
plt.plot(example_df["dish washer"][:60*60*24])
