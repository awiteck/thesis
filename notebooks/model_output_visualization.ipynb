# %%
import json
import matplotlib.pyplot as plt
import numpy as np

# %%
idx = 1
# Step 1: Read the data from the JSON file
with open('../model_outputs/2024_2_20_outputtest_example_outputs.json', 'r') as file:
    data = json.load(file)
    
source = [sublist[0] for sublist in data['source_readings'][idx]]
expected_ex = source + data['expected'][idx]
predicted_ex =  source + data['predicted'][idx]

# print(predicted_ex)
# print(expected_ex)

# Step 2: Plotting
plt.figure(figsize=(10, 6))  # Set the figure size for better visibility



# Plot "predicted" in blue
plt.plot(predicted_ex, 'b-', label='Predicted')
# Plot "expected" in red
plt.plot(expected_ex, 'r-', label='Expected')

plt.title('Expected vs. Predicted')
plt.xlabel('Index')
plt.ylabel('Values')
plt.legend()
plt.show()

# %%
data
# Out:
# {'source_readings': [[[-1.1532278060913086, 0.1477353870868683, 1.0, 2.0],
#    [-1.3210686445236206, 0.11058641970157623, 2.0, 2.0],
#    [-1.4082387685775757, 0.0827246904373169, 3.0, 2.0],
#    [-1.4342368841171265, 0.04557572677731514, 4.0, 2.0],
#    [-1.3497430086135864, 0.00842676218599081, 5.0, 2.0],
#    [-1.1142306327819824, -0.010147719644010067, 6.0, 2.0],
#    [-0.793842077255249, -0.05658392608165741, 7.0, 2.0],
#    [-0.40998753905296326, -0.10302013158798218, 8.0, 2.0],
#    [-0.23755884170532227, -0.10302013158798218, 9.0, 2.0],
#    [-0.15497659146785736, 0.01771400310099125, 10.0, 2.0],
#    [-0.0857757180929184, 0.21274606883525848, 11.0, 2.0],
#    [-0.07812921702861786, 0.37991639971733093, 12.0, 2.0],
#    [-0.1339486986398697, 0.5935229659080505, 13.0, 2.0],
#    [-0.08806966990232468, 0.7514060735702515, 14.0, 2.0],
#    [-0.03148553520441055, 0.732831597328186, 15.0, 2.0],
#    [0.20096822082996368, 0.7235443592071533, 16.0, 2.0],
#    [0.545060932636261, 0.7421188354492188, 17.0, 2.0],
#    [0.7438700795173645, 0.9000019431114197, 18.0, 2.0],
#    [0.7002849578857422, 1.1600446701049805, 19.0, 2.0],
#    [0.602027416229248, 1.1693319082260132, 20.0, 2.0],
#    [0.5144749283790588, 1.076459527015686, 21.0, 2.0],
#    [0.2460825890302658, 0.9464381337165833, 22.0, 2.0],
#    [-0.14924171566963196, 0.7699805498123169, 23.0, 2.0],
#    [-0.5388311147689819, 0.5006505250930786, 0.0, 2.0]]],
#  'expected': [[-0.7651676535606384,
#    -0.9685646891593933,
#    -1.069116234779358,
#    -1.0798213481903076,
#    -1.0851739645004272,
#    -1.0477060079574585,
#    -0.9395079612731934,
#    -0.7701379060745239,
#    -0.7062895894050598,
#    -0.46810096502304077,
#    -0.4665716588497162,
#    -0.43751493096351624,
#    -0.40998753905296326,
#    -0.2918490171432495,
#    -0.1935914307832718,
#    -0.1756221503019333,
#    -0.17829842865467072,
#    -0.12171429395675659,
#    -0.04601389169692993,
#    -0.07201200723648071,
#    -0.08654037117958069,
#    -0.2452053427696228,
#    -0.5762990117073059,
#    -0.8806298971176147]],
#  'predicted': [[-0.8467210531234741,
#    -1.0609771013259888,
#    -1.2094666957855225,
#    -1.3182761669158936,
#    -1.3792558908462524,
#    -1.4260367155075073,
#    -1.4639140367507935,
#    -1.5817803144454956,
#    -1.655829906463623,
#    -1.7144397497177124,
#    -1.7794679403305054,
#    -1.84952974319458,
#    -1.881091594696045,
#    -1.899093747138977,
#    -1.9246171712875366,
#    -1.9569796323776245,
#    -1.97758948802948,
#    -1.9854398965835571,
#    -1.9859031438827515,
#    -1.9732662439346313,
#    -1.9677711725234985,
#    -1.9713531732559204,
#    -1.9553261995315552,
#    -1.9601398706436157]]}

# %%
def generate_prediction_figure1(data):
    
    output_length=24
    
    observed = []
    preds = []
    
    plt.figure(figsize=(16, 6))
    
    num_preds = len(data['expected'])//4
    for i in range(0, num_preds):
        source = [sublist[0] for sublist in data['source_readings'][i]]
        pred = data['predicted'][i]
        obs = data['expected'][i]
        
        x_values = range(24*3*(i),24*(3*(i)+1),1)
        plt.plot(x_values, source, marker='.', linestyle='-', c='g')
        
        x_values = range(24*(3*i+1),24*(3*i+1)+output_length,1)
        plt.plot(x_values, pred, marker='.', linestyle='-', c='r')
        plt.plot(x_values, obs, marker='.', linestyle='-', c='b')
        
        observed += obs
#         observed += source
        preds += pred
    
        
    # Plot "predicted" in blue
#     plt.plot(preds, 'b-', label='Predicted')
    
    # Plot "expected" in red
#     plt.plot(observed, 'r-', label='Expected')

    plt.title('Expected vs. Predicted')
    plt.xlabel('Index')
    plt.ylabel('Values')
    plt.show()

# %%
generate_prediction_figure1(data)

# %%
def generate_prediction_figure2(data):
    '''
    Generate a figure that looks like Fig 13. in L'Heareaux et al's paper. 
    NOTE: DATA must be in chronological order. For example data['source_readings'][0] 
    should be the actual source readings right before data['source_readings'][1]
    Also prediction length must equal source length. Just to make the figure look 
    as expected. 
    '''
    
    observed = []
    preds = []
    
    num_preds = len(data['expected'])
    for i in range(0, num_preds-1):
        source = [sublist[0] for sublist in data['source_readings'][i+1]]
        pred = data['predicted'][i]
        obs = data['expected'][i]
        observed += source
        preds += pred
    plt.figure(figsize=(10, 6))
    
    # Plot "predicted" in blue
    plt.plot(preds, 'b-', label='Predicted')
    
    # Plot "expected" in red
    plt.plot(observed, 'r-', label='Expected')

    plt.title('Expected vs. Predicted')
    plt.xlabel('Index')
    plt.ylabel('Values')
    plt.legend()
    plt.show()

# %%
generate_prediction_figure(data)

# %%
def generate_prediction_figure(data):
    '''
    Generate a figure that looks like Fig 13. in Vaswani et al's paper. 
    NOTE: DATA must be in chronological order. For example data['source_readings'][0] 
    should be the actual source readings right before data['source_readings'][1]
    Also prediction length must equal source length. Just to make the figure look 
    as expected. 
    '''
    
    observed = []
    preds = []
    
    plt.figure(figsize=(10, 6))
    
    num_preds = len(data['expected'])
    for i in range(0, num_preds-1):
        source = [sublist[0] for sublist in data['source_readings'][i+1]]
        pred = data['predicted'][i]
        obs = data['expected'][i]
        x_values = range(24*i,24*(i+1),1)
        plt.plot(x_values, pred, marker='.', linestyle='-', c='r')
        plt.plot(x_values, obs, marker='.', linestyle='-', c='b')
        
        observed += obs
#         observed += source
        preds += pred
    
        
    # Plot "predicted" in blue
#     plt.plot(preds, 'b-', label='Predicted')
    
    # Plot "expected" in red
#     plt.plot(observed, 'r-', label='Expected')

    plt.title('Expected vs. Predicted')
    plt.xlabel('Index')
    plt.ylabel('Values')
    plt.legend()
    plt.show()

# %%
idx = 1
# Step 1: Read the data from the JSON file
with open('../model_outputs/2024_2_21_eia_novars_example_outputs.json', 'r') as file:
    data = json.load(file)
    
source = [sublist[0] for sublist in data['source_readings'][idx]]
expected_ex = source + data['expected'][idx]
predicted_ex =  source + data['predicted'][idx]

# print(predicted_ex)
# print(expected_ex)

# Step 2: Plotting
plt.figure(figsize=(10, 6))  # Set the figure size for better visibility



# Plot "predicted" in blue
plt.plot(predicted_ex, 'b-', label='Predicted')
# Plot "expected" in red
plt.plot(expected_ex, 'r-', label='Expected')

plt.title('Expected vs. Predicted')
plt.xlabel('Index')
plt.ylabel('Values')
plt.legend()
plt.show()

# %%
generate_prediction_figure1(data)
